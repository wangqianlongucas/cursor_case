# %%
from train import *

# %%
# Set random seed for reproducibility
np.random.seed(42)

# Train the agent
print("Starting training...")
episode_rewards, total_distances, env, best_distance, best_path = train(num_episodes=2000, num_cities=10)

# Plot final results
plot_final_results(episode_rewards, total_distances, env, best_distance, best_path)
# Out:
# Starting training...
# Training: 100%|██████████| 2000/2000 [00:00<00:00, 12531.57it/s]
# Episode 200
# Average Reward (last 200): 11.86
# Average Distance (last 200): 541.61
# Best Distance So Far: 366.97
# Current Epsilon: 0.330
#
# Episode 400
# Average Reward (last 200): 12.75
# Average Distance (last 200): 536.92
# Best Distance So Far: 360.16
# Current Epsilon: 0.121
#
# Episode 600
# Average Reward (last 200): 15.36
# Average Distance (last 200): 524.82
# Best Distance So Far: 340.67
# Current Epsilon: 0.044
#
# Episode 800
# Average Reward (last 200): 19.17
# Average Distance (last 200): 503.95
# Best Distance So Far: 325.03
# Current Epsilon: 0.016
#
# Episode 1000
# Average Reward (last 200): 19.79
# Average Distance (last 200): 506.23
# Best Distance So Far: 325.03
# Current Epsilon: 0.010
#
# Episode 1200
# Average Reward (last 200): 21.95
# Average Distance (last 200): 501.75
# Best Distance So Far: 325.03
# Current Epsilon: 0.010
#
# Episode 1400
# Average Reward (last 200): 21.96
# Average Distance (last 200): 501.71
# Best Distance So Far: 325.03
# Current Epsilon: 0.010
#
# Episode 1600
# Average Reward (last 200): 21.68
# Average Distance (last 200): 503.03
# Best Distance So Far: 325.03
# Current Epsilon: 0.010
#
# Episode 1800
# Average Reward (last 200): 21.75
# Average Distance (last 200): 502.85
# Best Distance So Far: 325.03
# Current Epsilon: 0.010
#
# Episode 2000
# Average Reward (last 200): 21.50
# Average Distance (last 200): 504.52
# Best Distance So Far: 325.03
# Current Epsilon: 0.010
# Training Summary:
# Best distance found: 325.03
# Best path: [0, 5, 3, 2, 7, 9, 6, 1, 4, 8]
# Final average reward (last 100): 21.77
# Final average distance (last 100): 503.66

# %%
from compare_methods import *

# %%
q_results, dqn_results, random_avg, random_best = compare_methods(
        num_episodes=3000,
        num_cities=10,
        seed=42
    )
# Out:
# Comparing Q-Learning vs DQN on 10-city TSP
# Training episodes: 3000
# Random seed: 42
# ============================================================
# Training Q-Learning: 100%|██████████| 3000/3000 [00:00<00:00, 10046.95it/s]
# Using device: cpu
# Training DQN: 100%|██████████| 3000/3000 [01:31<00:00, 32.86it/s]
# Calculating random baseline...
# Random baseline: 100%|██████████| 1000/1000 [00:00<00:00, 11097.66it/s]
# ============================================================
# COMPARISON RESULTS
# ============================================================
#
# Q-Learning:
#   Best Distance: 325.03
#   Best Path: [0, 5, 3, 2, 7, 9, 6, 1, 4, 8]
#   Final Avg Distance (last 100): 381.74
#   Training Time: 0.31 seconds
#
# DQN:
#   Best Distance: 290.31
#   Best Path: [0, 4, 1, 6, 9, 7, 2, 8, 3, 5]
#   Final Avg Distance (last 100): 423.55
#   Training Time: 91.30 seconds
#
# Random Baseline:
#   Average Distance: 558.02
#   Best Distance: 353.60
#
# Improvement over Random:
#   Q-Learning: 1.72x
#   DQN: 1.92x
#
# DQN is 1.12x better than Q-Learning
